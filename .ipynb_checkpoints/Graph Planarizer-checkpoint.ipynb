# %%
import networkx as nx
from nxpd import draw, nxpdParams
import itertools as it
from networkx.algorithms import bipartite
import planarity
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import time
import pygraphviz as pgv

startInstantTime = time.time()

# %%
#Program's running parameters
inputFilename = "./Input/Input.txt"

greenRGBColor = (35, 155, 86)
redRGBColor = (176, 58, 46)

# %%
def printColouredText(text, foregroundColor = (0, 0, 0), backgroundColor = (255, 255, 255)):
    return "\033[48;2;{};{};{}m\033[38;2;{};{};{}m{}\033[38;2;0;0;0m\033[48;2;255;255;255m".format(backgroundColor[0], backgroundColor[1], backgroundColor[2], foregroundColor[0], foregroundColor[1], foregroundColor[2], text)

def addEdgeInUndirectedGraph(graph, initialNode, finalNode, cost = 1.0):
    if initialNode not in graph:
        graph[initialNode] = {}
    graph[initialNode][finalNode] = cost
    if finalNode not in graph:
        graph[finalNode] = {}
    graph[finalNode][initialNode] = cost

"""
def verificarSiGrafoEsBipartito(grafo, nodesList):
    color = {}
    for each_node in nodesList:
       #if not visited already
        if each_node not in color.keys():
            neighbors = [each_node]
            next_neighbors = []
            curr_color = True
            while neighbors:
                out = neighbors.pop(0)
                if out in color.keys():
                    #Check if current color is intended color
                    if color[out] != curr_color:
                        return False
                else:
                    color[out] = curr_color
                    for i in grafo[out]:
                        next_neighbors.append(i)
                if neighbors == []:
                    curr_color = not curr_color
                    neighbors, next_neighbors = next_neighbors, neighbors
    return True
"""
# Out:
# '\ndef verificarSiGrafoEsBipartito(grafo, nodesList):\n    color = {}\n    for each_node in nodesList:\n       #if not visited already\n        if each_node not in color.keys():\n            neighbors = [each_node]\n            next_neighbors = []\n            curr_color = True\n            while neighbors:\n                out = neighbors.pop(0)\n                if out in color.keys():\n                    #Check if current color is intended color\n                    if color[out] != curr_color:\n                        return False\n                else:\n                    color[out] = curr_color\n                    for i in grafo[out]:\n                        next_neighbors.append(i)\n                if neighbors == []:\n                    curr_color = not curr_color\n                    neighbors, next_neighbors = next_neighbors, neighbors\n    return True\n'

# %%
graph = {}
nodesList = []

inputStream = open(inputFilename, "r")
for textLine in inputStream.readlines():
    collectedNodes = textLine.strip().split(" - ")
    addEdgeInUndirectedGraph(graph, collectedNodes[0].strip(), collectedNodes[1].strip())
    
    #The graph's nodes list is updated also
    if collectedNodes[0].strip() not in nodesList:
        nodesList.append(collectedNodes[0].strip())
    if collectedNodes[1].strip() not in nodesList:
        nodesList.append(collectedNodes[1].strip())

nodesList.sort()
print(nodesList)
# Out:
# ['Account', 'AccountActivation', 'AccountInEarlyChurn', 'AccountInWinback', 'ActivationsGoalAgreement', 'AdherenceFeePayment', 'BaseCommissionAgreement', 'BonusByRecurrentPaymentAgreement', 'BonusByZoneAgreement', 'Canton', 'CommissionDiscount', 'CommissionLiquidation', 'Country', 'Customer', 'Department', 'Location', 'MasterDealer', 'Municipality', 'Parish', 'PenaltyDetail', 'Plan', 'Province', 'RecurrentPaymentSignUp', 'Sale']

# %%
networkxGraph = nx.Graph()
networkxGraph.graph['rankdir'] = 'LR'
networkxGraph.graph['dpi'] = 120

for node in nodesList:
    networkxGraph.add_node(node, color = "black", style = "filled", fillcolor = "pink")

for initialNode in graph:
    for finalNode in graph[initialNode]:
        networkxGraph.add_edge(initialNode, finalNode, weight = graph[initialNode][finalNode])

#G.add_node(0, color='red', style='filled', fillcolor='pink')
#G.add_node(1, shape='square')
#G.add_node(3, style='filled', fillcolor='#00ffff')
#G.add_edge(0, 1, color='red', style='dashed')
#G.add_edge(3, 3, label='a')
#plt.figure(num = 1, figsize = (15, 14))
display(draw(networkxGraph, show = 'ipynb'))
#plt.show()


#import random

#G = nx.Graph()
#G.add_nodes_from([1,2])
#G.add_edge(1, 2, weight=random.randint(1, 10))

#draw(G, show='ipynb')


"""
for initialNode in graph:
    for finalNode in graph[initialNode]:
        networkxGraph.add_edge(initialNode, finalNode, weight = graph[initialNode][finalNode])

avail_font_names = [f.name for f in mpl.font_manager.fontManager.ttflist]
print(avail_font_names)

plt.figure(num = 1, figsize = (15, 14))
nx.draw(networkxGraph, with_labels = True, node_size = [len(v) * 100 for v in nodesList], font_family = "Sawasdee" , font_size = 13)
plt.show()
"""
# Out:
# '\nfor initialNode in graph:\n    for finalNode in graph[initialNode]:\n        networkxGraph.add_edge(initialNode, finalNode, weight = graph[initialNode][finalNode])\n\navail_font_names = [f.name for f in mpl.font_manager.fontManager.ttflist]\nprint(avail_font_names)\n\nplt.figure(num = 1, figsize = (15, 14))\nnx.draw(networkxGraph, with_labels = True, node_size = [len(v) * 100 for v in nodesList], font_family = "Sawasdee" , font_size = 13)\nplt.show()\n'

# %%
is_planar, P = nx.check_planarity(networkxGraph, counterexample = True)
print(is_planar)
print(P)

plt.figure(num = 2, figsize = (15, 14))
nx.draw(P)
plt.show()
# Out:
# False
# Graph with 6 nodes and 11 edges

# %%
print(planarity.is_planar(networkxGraph)) # False

# find forbidden Kuratowski subgraph
K = planarity.kuratowski_subgraph(networkxGraph)

print(K) # K5 edges
# Out:
# False
# Graph with 9 nodes and 14 edges
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge AccountActivation-Account
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge AccountInEarlyChurn-Account
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge AccountInWinback-AccountInEarlyChurn
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge AdherenceFeePayment-Account
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionDiscount-AccountInEarlyChurn
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionDiscount-AccountInWinback
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-CommissionDiscount
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-AccountActivation
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-AdherenceFeePayment
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-BaseCommissionAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-BonusByZoneAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge CommissionLiquidation-BonusByRecurrentPaymentAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Country-Canton
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Customer-Account
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Department-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Location-AccountActivation
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Location-BonusByZoneAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Location-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Location-Department
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Location-Canton
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge MasterDealer-ActivationsGoalAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge MasterDealer-BaseCommissionAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge MasterDealer-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Municipality-Location
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Municipality-Department
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Municipality-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Parish-Location
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Parish-Canton
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Parish-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge PenaltyDetail-CommissionLiquidation
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Plan-BaseCommissionAgreement
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Province-Location
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Province-Country
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Province-Canton
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Province-Parish
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge RecurrentPaymentSignUp-Account
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Sale-AccountActivation
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Sale-MasterDealer
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Sale-Customer
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_functions.py:8: UserWarning: ignoring parallel edge Sale-Plan
#   return planarity.PGraph(graph).is_planar()
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge AccountActivation-Account
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge AccountInEarlyChurn-Account
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge AccountInWinback-AccountInEarlyChurn
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge AdherenceFeePayment-Account
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionDiscount-AccountInEarlyChurn
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionDiscount-AccountInWinback
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-CommissionDiscount
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-AccountActivation
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-AdherenceFeePayment
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-BaseCommissionAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-BonusByZoneAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge CommissionLiquidation-BonusByRecurrentPaymentAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Country-Canton
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Customer-Account
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Department-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Location-AccountActivation
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Location-BonusByZoneAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Location-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Location-Department
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Location-Canton
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge MasterDealer-ActivationsGoalAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge MasterDealer-BaseCommissionAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge MasterDealer-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Municipality-Location
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Municipality-Department
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Municipality-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Parish-Location
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Parish-Canton
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Parish-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge PenaltyDetail-CommissionLiquidation
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Plan-BaseCommissionAgreement
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Province-Location
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Province-Country
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Province-Canton
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Province-Parish
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge RecurrentPaymentSignUp-Account
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Sale-AccountActivation
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Sale-MasterDealer
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Sale-Customer
#   pgraph = planarity.PGraph(graph)
# /usr/local/lib/python3.10/dist-packages/planarity/planarity_networkx.py:13: UserWarning: ignoring parallel edge Sale-Plan
#   pgraph = planarity.PGraph(graph)

# %%
numeroEjes = len(networkxGraph.edges())
found = False
for i in range(1, numeroEjes):
    if found == True:
        break
    print("Eliminando", i, "eje(s)")
    for subEdgesList in it.combinations(networkxGraph.edges(), i):
        grafoNuevo = networkxGraph.copy()
        for edge in subEdgesList:
            grafoNuevo.remove_edge(edge[0], edge[1])
        esSubgrafoPlanar = planarity.is_planar(grafoNuevo)
        if esSubgrafoPlanar == True:
            print(subEdgesList, grafoNuevo)
            plt.figure(num = 3, figsize = (15, 14))
            nx.draw_planar(grafoNuevo, with_labels = True, alpha = 0.8)
            plt.show()
            found = True
            break
# Out:
# Eliminando 1 eje(s)
# Eliminando 2 eje(s)
# (('Canton', 'Location'), ('Location', 'Canton')) DiGraph with 24 nodes and 78 edges

# %%
outputStream = open(nombreArchivoSalida, "w")
outputStream.write(str(numeroVerticesAlto) + "\n")
outputStream.write(str(numeroVerticesAncho) + "\n")
outputStream.write(informacionGrafoMalla)
outputStream.close()
print("Se ha generado el archivo", printColouredText(nombreArchivoSalida, colorTextoVerde), "que contiene la información del grafo generado")

endInstantTime = time.time()
fullRunningTime = endInstantTime - startInstantTime
runningTimeInMinutes = int(fullRunningTime / 60)
runningTimeInSeconds = int(fullRunningTime % 60)
print("Tiempo de Ejecución: {} minuto(s) y {} segundo(s)".format(runningTimeInMinutes, runningTimeInSeconds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 outputStream = open(nombreArchivoSalida, "w")
#       2 outputStream.write(str(numeroVerticesAlto) + "\n")
#       3 outputStream.write(str(numeroVerticesAncho) + "\n")
#
# NameError: name 'nombreArchivoSalida' is not defined
